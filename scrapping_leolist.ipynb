# %%
#using web crawlers
import scrapy
from scrapy.crawler import CrawlerProcess
import response
import csv

# %%
#define the spider class
from typing import Any, Iterable


from scrapy.http import Request, Response


class LeoSpider(scrapy.Spider):
    #name of the crawler
    name = "leo_spider"

    #create the start requests
    def start_requests(self) -> Iterable[Request]:
        urls = [ 'https://www.leolist.cc/motors/cars-trucks-rv/greater-toronto',
               'https://www.leolist.cc/motors/cars-trucks-rv/greater-toronto']
        for url in urls:
            yield scrapy.Request(url=url, callback=self.parse)

    #the next site the link should follow
    def parse(self, response: Response, **kwargs: Any) -> Any:
       ggggggggggggg
       print(response)
       links = response.css('div.group > div.lst list-item > a::attr(href)').extract()
       for link in links:
           yield response.follow(url=link, callback=self.parse_next) 

    #next site to follow
    def parse_next(self, response):
        #direct to the item-name
        item_name = response.css('div.user-data > div.value ::text').extract().strip()
        more_info = response.css('div.user-data > div.user-label ::text').extract().strip()
        item_info = item_name + ' ' + more_info
        #extract the image links
        ftftf
        img_link = response.css('div.simple-gallery > a::main-image(href)').extract().strip()
        
        #save the data in a dictionary
        img_data[item_info] = img_link

        # Save the data to a CSV file
        with open('img_data.csv', mode='a', newline='') as file:
            writer = csv.writer(file)
            writer.writerow([item_info, img_link])


img_data = dict()

process = CrawlerProcess() 
process.crawl(LeoSpider)
process.start()
# Out:
# 2024-09-10 10:50:38 [scrapy.utils.log] INFO: Scrapy 2.11.2 started (bot: scrapybot)
# 2024-09-10 10:50:38 [scrapy.utils.log] INFO: Versions: lxml 5.2.2.0, libxml2 2.11.7, cssselect 1.2.0, parsel 1.9.1, w3lib 2.2.1, Twisted 24.7.0, Python 3.12.1 (tags/v3.12.1:2305ca5, Dec  7 2023, 22:03:25) [MSC v.1937 64 bit (AMD64)], pyOpenSSL 24.2.1 (OpenSSL 3.3.1 4 Jun 2024), cryptography 43.0.0, Platform Windows-11-10.0.22631-SP0
# 2024-09-10 10:50:38 [scrapy.addons] INFO: Enabled addons:
# []
# 2024-09-10 10:50:38 [py.warnings] WARNING: C:\Users\HP\AppData\Roaming\Python\Python312\site-packages\scrapy\utils\request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
# ...
